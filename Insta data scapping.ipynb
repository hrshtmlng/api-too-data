# %%
import requests

url = "https://instagram-scraper-api2.p.rapidapi.com/v1/likes"

querystring = {"code_or_id_or_url":"CxYQJO8xuC6"}

headers = {
	"x-rapidapi-key": "864431620amshdd161f7dd13cee6p1244eejsn3d9c2f1e76fb",
	"x-rapidapi-host": "instagram-scraper-api2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'data': {'count': 883, 'items': [{'full_name': '리아', 'id': '67094871436', 'is_new': False, 'is_private': False, 'is_verified': False, 'latest_reel_media': 0, 'profile_pic_id': '3395111464940612704', 'profile_pic_url': 'https://scontent-fra5-2.cdninstagram.com/v/t51.2885-19/448680581_1016454216528690_4252224550853922447_n.jpg?stp=dst-jpg_e0_s150x150&_nc_ht=scontent-fra5-2.cdninstagram.com&_nc_cat=106&_nc_ohc=morhMLWSM94Q7kNvgHuQV8R&edm=AHUBisUBAAAA&ccb=7-5&oh=00_AYAOkLaewo5-1-O4VTdLiL3hk5QNrZSFrZ7ac050kVAdfA&oe=667B672B&_nc_sid=bc52df', 'username': 'sun2597x'}, {'full_name': 'Franco Marinelli', 'id': '44184551852', 'is_new': False, 'is_private': False, 'is_verified': False, 'latest_reel_media': 0, 'profile_pic_url': 'https://instagram.fkhi17-1.fna.fbcdn.net/v/t51.2885-19/44884218_345707102882519_2446069589734326272_n.jpg?_nc_ht=instagram.fkhi17-1.fna.fbcdn.net&_nc_cat=1&_nc_ohc=d38vMPEBHWwQ7kNvgE7t1YW&edm=AEaYFD0BAAAA&ccb=7-5&ig_cache_key=YW5vbnltb3VzX3Byb2ZpbGVfcGlj.2-ccb7-5&oh=00_A
# ...

# %%
import pyforest

# %%
temp_df = pd.DataFrame(response.json()['data']['items'])[['id','full_name','username','is_new','is_private','is_verified']]

# %%
temp_df.head()
# Out:
#             id         full_name                username  is_new  is_private  \
# 0  67094871436                리아                sun2597x   False       False
# 1  44184551852  Franco Marinelli  franco.marinelli.73157   False       False
# 2  54518921145   Varalakshmi M C           varalakshmimc   False       False
# 3  49603539734         Nitai Sit            nitai.sit.92   False       False
# 4  67489906878      Pankaj kumar     pankaj__letter__boy   False       False
#
#    is_verified
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
temp_df.shape
# Out:
# (883, 6)

# %%
temp_df.to_csv('ig.csv')

# %%
temp_df
# Out:
#               id         full_name                username  is_new  \
# 0    67094871436                리아                sun2597x   False
# 1    44184551852  Franco Marinelli  franco.marinelli.73157   False
# 2    54518921145   Varalakshmi M C           varalakshmimc   False
# 3    49603539734         Nitai Sit            nitai.sit.92   False
# 4    67489906878      Pankaj kumar     pankaj__letter__boy   False
# ..           ...               ...                     ...     ...
# 878  50045830141    Instagram user   official_tushar_uk_08   False
# 879   1818038453      🔱کوروش_گردی🔱            korosh_gardi   False
# 880  49611127018    Srihitha Reddy            srihitha_684   False
# 881  61227282530     Zillur Rehman         mr.zillurrahman   False
# 882  61882029401      Ravi Mohalai      india_travel_rj.29   False
#
#      is_private  is_verified
# 0         False        False
# 1         False        False
# 2         False        False
# 3         False        False
# ...
